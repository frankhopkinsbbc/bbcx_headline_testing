# %% [markdown]
# # BBC Studios Homepage Headline Testing

# %% [markdown]
# ## Test Notebook for all functions

# %%
import sys
import bbcx_headline_py

# %%
bbcx_headline_py.headline_summary_stats()
# Out:
# {'experiment_count': 196,
#  'average_conversion_rate': 2.82,
#  'treatment_group_count': 472,
#  'winning_variants_percentage': 39.83,
#  'statistical_significance_percentage': 61.7,
#  'overall_win_rate': 24.58,
#  'average_uplift': 0.44,
#  'max_uplift': 323.88,
#  'min_uplift': -76.51,
#  'std_uplift': 0.48,
#  't_stat_questions_vs_statements': -0.17,
#  'p_val_questions_vs_statements': 0.87,
#  'p_val_time_of_day': 0.0}

# %%
bbcx_headline_py.headline_visualisations()

# %%
bbcx_headline_py.headline_sentiment_analysis()
# Out:
# 0.02458506087924472 0.5255587133005871
# 0.14188657557246037 0.0002317019250455798
# {'average_polarity': 0.06237087132266504,
#  'average_subjectivity': 0.23991752351617823}
